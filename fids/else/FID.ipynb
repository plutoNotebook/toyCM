# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

one_step = {
    "vanilla": "vanilla/metric-fid50k_full.jsonl",
    "sig150": "sig150/metric-fid50k_full.jsonl",
    "sig100": "sig100/metric-fid50k_full.jsonl",
    "sig50": "sig50/metric-fid50k_full.jsonl",
    "con150": "con150/metric-fid50k_full.jsonl",
    "con125": "con125/metric-fid50k_full.jsonl",
    "con100": "con100/metric-fid50k_full.jsonl",
    "step_sig": "sigstep/metric-fid50k_full.jsonl",
    "step_con": "constep/metric-fid50k_full.jsonl",
    "g04s100" : "g04s100/metric-fid50k_full.jsonl",
    "g04s150" : "g04s150/metric-fid50k_full.jsonl",
    "s02g05s100": "s02g05s100/metric-fid50k_full.jsonl",
    "s02g05s100k4": "s02g05s100k4/metric-fid50k_full.jsonl",
    "s03g05s100c": "s03g05s100c/metric-fid50k_full.jsonl",  
    "s03g05s100k4": "s03g05s100k4/metric-fid50k_full.jsonl" 
}

two_step = {
    "vanilla": "vanilla/metric-two_step_fid50k_full.jsonl",
    "sig150": "sig150/metric-two_step_fid50k_full.jsonl",
    "sig100": "sig100/metric-two_step_fid50k_full.jsonl",
    "sig50": "sig50/metric-two_step_fid50k_full.jsonl",
    "con150": "con150/metric-two_step_fid50k_full.jsonl",
    "con125": "con125/metric-two_step_fid50k_full.jsonl",
    "con100": "con100/metric-two_step_fid50k_full.jsonl",
    "step_sig": "sigstep/metric-two_step_fid50k_full.jsonl",
    "step_con": "constep/metric-two_step_fid50k_full.jsonl",
    "g04s100" : "g04s100/metric-two_step_fid50k_full.jsonl",
    "g04s150" : "g04s150/metric-two_step_fid50k_full.jsonl",
    "s02g05s100": "s02g05s100/metric-two_step_fid50k_full.jsonl",  
    "s02g05s100k4": "s02g05s100k4/metric-two_step_fid50k_full.jsonl",
    "s03g05s100c": "s03g05s100c/metric-two_step_fid50k_full.jsonl",  
    "s03g05s100k4": "s03g05s100k4/metric-two_step_fid50k_full.jsonl" 
}


colors = {
    "vanilla": "#1f77b4",  # 기존 색상
    "sig150": "#ff7f0e",    # 기존 색상
    "sig100": "#ff6347",    # 기존 색상
    "sig50": "#ff4500",     # 기존 색상
    "con150": "#2ca02c",    # 기존 색상
    "con125": "#17a2b8",    # 기존 색상
    "con100": "#d62728",    # 기존 색상
    "step_sig": "#9467bd",  # 기존 색상
    "step_con": "#8c564b",  # 기존 색상
    "g04s100": "#e377c2",   # 새로운 색상
    "g04s150": "#7f7f7f",   # 새로운 색상
    "s02g05s100": "#a6d96f",  # 새로운 색상
    "s02g05s100k4": "#f7b7a3",  # 새로운 색상
    "s03g05s100c": "#f1c232",  # 새로운 색상
    "s03g05s100k4": "#c39bd3"  # 새로운 색상
}
# 그래프 초기화
plt.figure(figsize=(12, 8))

# 각 파일 데이터를 읽고 플롯
for label, filepath in one_step.items():
    # 데이터 로드
    data = []
    with open(filepath, 'r') as file:
        for line in file:
            data.append(json.loads(line.strip()))
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(data)
    df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
    # 그래프 그리기
    plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# 그래프 꾸미기
plt.xlabel('Index')
plt.ylabel('FID50k Full')
plt.title('FID50k Full Comparison Across Models')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 그래프 초기화
plt.figure(figsize=(12, 8))

# 각 파일 데이터를 읽고 플롯
for label, filepath in two_step.items():
    # 데이터 로드
    data = []
    with open(filepath, 'r') as file:
        for line in file:
            data.append(json.loads(line.strip()))
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(data)
    df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
    # 그래프 그리기
    plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# 그래프 꾸미기
plt.xlabel('Index')
plt.ylabel('FID50k Full')
plt.title('Two-step-FID50k Full Comparison Across Models')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

one_step = {
    "Consistency Distillation": "cd/metric-fid50k_full.jsonl",
    "Consistency Training": "vanilla/metric-fid50k_full.jsonl",
    #"Ours": "ourstf/metric-fid50k_full.jsonl"
}

# two_step = {
#     "Consistency Distillation": "cd/metric-two_step_fid50k_full.jsonl",
#     "Consistency Training": "vanilla/metric-two_step_fid50k_full.jsonl",
#     "Ours": "sigstep/metric-two_step_fid50k_full.jsonl",
# }

colors = {
    "Consistency Distillation": "#1f77b4",  # 기존 색상
    "Consistency Training": "#ff7f0e",    # 기존 색상
    #"Ours": "#ff6347",    # 기존 색상
}

# 그래프 초기화
plt.figure(figsize=(12, 8))

# 각 파일 데이터를 읽고 플롯
for label, filepath in one_step.items():
    # 데이터 로드
    data = []
    with open(filepath, 'r') as file:
        for line in file:
            data.append(json.loads(line.strip()))
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(data)
    df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
    # 그래프 그리기
    plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# 그래프 꾸미기
#plt.yscale('log')  # y축을 로그 스케일로 변환
plt.xlabel('Index')
plt.ylabel('FID50k Full (Log Scale)')
plt.title('FID50k Full Comparison Across Models (Log Scale)')
plt.legend()
plt.grid(True, which="both", linestyle='--')  # 로그 스케일에서는 'both'로 설정
plt.tight_layout()
plt.show()

# # 그래프 초기화
# plt.figure(figsize=(12, 8))

# # 각 파일 데이터를 읽고 플롯
# for label, filepath in two_step.items():
#     # 데이터 로드
#     data = []
#     with open(filepath, 'r') as file:
#         for line in file:
#             data.append(json.loads(line.strip()))
    
#     # pandas DataFrame으로 변환
#     df = pd.DataFrame(data)
#     df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
#     # 그래프 그리기
#     plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# # 그래프 꾸미기
# plt.yscale('log')  # y축을 로그 스케일로 변환
# plt.xlabel('Index')
# plt.ylabel('FID50k Full (Log Scale)')
# plt.title('Two-step-FID50k Full Comparison Across Models (Log Scale)')
# plt.legend()
# plt.grid(True, which="both", linestyle='--')  # 로그 스케일에서는 'both'로 설정
# plt.tight_layout()
# plt.show()

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

one_step = {
    "Consistency Training": "vanilla/metric-fid50k_full.jsonl",
    "Ours(double:150)": "sig150/metric-fid50k_full.jsonl",
    "Ours(double:100)": "sig100/metric-fid50k_full.jsonl",
    "Ours(double:50)": "sig50/metric-fid50k_full.jsonl",

}

two_step = {
    "Consistency Training": "vanilla/metric-two_step_fid50k_full.jsonl",
    "Ours(double:150)": "sig150/metric-two_step_fid50k_full.jsonl",
    "Ours(double:100)": "sig100/metric-two_step_fid50k_full.jsonl",
    "Ours(double:50)": "sig50/metric-two_step_fid50k_full.jsonl",

}


colors = {
    "Consistency Training": "#1f77b4",  # 기존 색상
    "Ours(double:150)": "#ff7f0e",    # 기존 색상
    "Ours(double:100)": "#d62728",    # 기존 색상
    "Ours(double:50)": "#8c564b",     # 기존 색상
}
# 그래프 초기화
plt.figure(figsize=(12, 8))

# 각 파일 데이터를 읽고 플롯
for label, filepath in one_step.items():
    # 데이터 로드
    data = []
    with open(filepath, 'r') as file:
        for line in file:
            data.append(json.loads(line.strip()))
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(data)
    df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
    # 그래프 그리기
    plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# 그래프 꾸미기
plt.xlabel('Index')
plt.ylabel('FID50k Full')
plt.title('FID50k Full Comparison Across Models')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 그래프 초기화
plt.figure(figsize=(12, 8))

# 각 파일 데이터를 읽고 플롯
for label, filepath in two_step.items():
    # 데이터 로드
    data = []
    with open(filepath, 'r') as file:
        for line in file:
            data.append(json.loads(line.strip()))
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(data)
    df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
    # 그래프 그리기
    plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# 그래프 꾸미기
plt.xlabel('Index')
plt.ylabel('FID50k Full')
plt.title('Two-step-FID50k Full Comparison Across Models')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

import json
import matplotlib.pyplot as plt
import pandas as pd



def plot_min_fid(data_files, title, exclude_last_n=0):
    min_values = {}
    for label, filepath in data_files.items():
        data = []
        with open(filepath, 'r') as file:
            for line in file:
                data.append(json.loads(line.strip()))
        df = pd.DataFrame(data)
        df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])

        # 마지막 n개 제외 (only for one_step)
        if exclude_last_n > 0:
            df = df[:-exclude_last_n]

        min_fid = df['fid50k_full'].min()
        min_values[label] = min_fid

    # 선 그래프 그리기
    plt.figure(figsize=(12, 8))
    for label, min_fid in min_values.items():
        plt.plot(label, min_fid, 'o-', color=colors[label], label=f"{label} (min: {min_fid:.2f})")
        plt.text(label, min_fid, f"{min_fid:.2f}", fontsize=10, ha='center', va='bottom')

    plt.title(title, fontsize=14)
    plt.xlabel("Model", fontsize=12)
    plt.ylabel("Min FID50k Full", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(rotation=45)
    plt.legend(loc='upper right')
    plt.tight_layout()
    plt.show()

# One-step FID 그래프 (마지막 3개 제외)
plot_min_fid(one_step, "One-step Min FID50k Full Comparison", exclude_last_n=3)

# Two-step FID 그래프
plot_min_fid(two_step, "Two-step Min FID50k Full Comparison")

# %%
class ECDLoss:
    def __init__(self, P_mean=-1.1, P_std=2.0, sigma_data=0.5, q=2, c=0.0, k=8.0, b=1.0, cut=4.0, adj='sigmoid', reg=False, lamd = 0.1, ):
        self.P_mean = P_mean
        self.P_std = P_std
        self.sigma_data = sigma_data
        
        self.reg = reg
        self.lamd = lamd
        
        if adj == 'const':
            self.t_to_r = self.t_to_r_const
            self.mu = self.mu_const
        elif adj == 'sigmoid':
            self.t_to_r = self.t_to_r_sigmoid
            self.mu = self.mu_sigmoid
        else:
            raise ValueError(f'Unknow schedule type {adj}!')

        self.q = q
        self.stage = 0
        self.ratio = 0.

        self.stage_mu = 0
        self.ratio_mu = 0.
        
        self.k = k
        self.b = b

        self.c = c

    def update_schedule(self, stage):
        self.stage = stage
        self.ratio = 1 - 1 / self.q ** (stage+1)

    def t_to_r_const(self, t):
        decay = 1 / self.q ** (self.stage+1)
        ratio = 1 - decay
        r = t * ratio
        return torch.clamp(r, min=0)

    def t_to_r_sigmoid(self, t):
        adj = 1 + self.k * torch.sigmoid(-self.b * t)
        decay = 1 / self.q ** (self.stage+1)
        ratio = 1 - decay * adj
        r = t * ratio
        return torch.clamp(r, min=0)
    
    def update_schedule_mu(self, stage_mu):
        self.stage_mu = stage_mu
        self.ratio_mu = 1 - 1 / self.q ** (stage_mu+1)

    def mu_const(self, t):
        decay = 1 / self.q ** (self.stage_mu+1)
        ratio = 1 - decay
        return torch.clamp(torch.tensor(ratio, dtype=t.dtype), min=0)
    
    def mu_sigmoid(self, t):
        adj = 1 + self.k * torch.sigmoid(-self.b * t)
        decay = 1 / self.q ** (self.stage_mu+1)
        ratio = 1 - decay * adj
        return torch.clamp(ratio, min=0)

    def __call__(self, net, images, labels=None, augment_pipe=None):
        # t ~ p(t) and r ~ p(r|t, iters) (Mapping fn)
        rnd_normal = torch.randn([images.shape[0], 1, 1, 1], device=images.device)
        t = (rnd_normal * self.P_std + self.P_mean).exp()
        r = self.t_to_r(t)

        # Augmentation if needed
        y, augment_labels = augment_pipe(images) if augment_pipe is not None else (images, None)
        
        # Shared noise direction
        eps   = torch.randn_like(y)
        eps_t = eps * t
        eps_r = eps * r

        # Shared Dropout Mask
        rng_state = torch.cuda.get_rng_state()
        yt = y + eps_t
        D_yt = net(yt, t, labels, augment_labels=augment_labels)
        
        if r.max() > 0:
            torch.cuda.set_rng_state(rng_state)
            with torch.no_grad():
                rt = r / t
                mu = self.mu(t)
                yr_hat = rt * yt + (1 - rt) * D_yt
                yr_bar = (1 - mu) * yr_hat + mu * (y + eps_r)
                D_yr = net(yr_bar, r, labels, augment_labels=augment_labels)
            
            mask = r > 0
            D_yr = torch.nan_to_num(D_yr)
            D_yr = mask * D_yr + (~mask) * y
        else:
            D_yr = y

        # L2 Loss
        loss = (D_yt - D_yr) ** 2
        if self.reg:
            loss = loss + self.lamd * ((yr_hat - (y + eps_r)) ** 2)
        loss = torch.sum(loss.reshape(loss.shape[0], -1), dim=-1)
        
        # Producing Adaptive Weighting (p=0.5) through Huber Loss
        if self.c > 0:
            loss = torch.sqrt(loss + self.c ** 2) - self.c
        else:
            loss = torch.sqrt(loss)
        
        # Weighting fn
        return loss / (t - r).flatten()

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# ECDLoss 클래스 인스턴스

# 설정
num_ticks = 2000  # 총 iteration 수
initial_lr = 0.7
gamma = 0.5
double = 10
stage = 0

# 그래프 데이터를 저장할 리스트
ratios = []

# 실제로 ecdloss 객체가 정의되었을 때, 해당 객체로부터 계산을 수행
for tick in range(num_ticks):
    rnd_normal = torch.randn([1, 1, 1, 1])
    t = (rnd_normal * ecdloss.P_std + ecdloss.P_mean).exp()  # t 계산
    r = ecdloss.t_to_r(t)  # r 계산
    
    new_stage = tick // double  # stage 업데이트
    if new_stage > stage:
        stage = new_stage
    
    adj = 1 + 8.0 * torch.sigmoid(-1.0 * t)  # 조정값 계산
    ratio = 1 - (0.7 * (gamma ** stage)) * adj  # ratio 계산
    ratio = torch.clamp(ratio, min=0)  # 비율을 0 이상으로 클램프

    ratios.append(ratio.item())  # ratio 값을 리스트에 저장

# 시각화
plt.plot(range(num_ticks), ratios)

# 그래프 꾸미기
plt.title("Values over Iterations with Different double and decay_base", fontsize=16)
plt.xlabel("Iteration", fontsize=14)
plt.ylabel("Ratio", fontsize=14)
plt.legend(fontsize=10, loc='upper right')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

one_step = {
    "vanilla": "vanilla/metric-fid50k_full.jsonl",
    "vanilla_stf": "vanilla_stf/metric-fid50k_full.jsonl",
    "our_stf": "ourstf/metric-fid50k_full.jsonl",
    "our": "sigstep/metric-fid50k_full.jsonl",

}

# two_step = {
#     "Consistency Training": "vanilla/metric-two_step_fid50k_full.jsonl",
#     "Ours(double:150)": "sig150/metric-two_step_fid50k_full.jsonl",
#     "Ours(double:100)": "sig100/metric-two_step_fid50k_full.jsonl",
#     "Ours(double:50)": "sig50/metric-two_step_fid50k_full.jsonl",

# }


colors = {
    "vanilla": "#1f77b4",  # 기존 색상
    "vanilla_stf": "#ff7f0e",    # 기존 색상
    "our_stf": "#d62728",    # 기존 색상
    "our": "#8c564b",     # 기존 색상
}
# 그래프 초기화
plt.figure(figsize=(12, 8))

# 각 파일 데이터를 읽고 플롯
for label, filepath in one_step.items():
    # 데이터 로드
    data = []
    with open(filepath, 'r') as file:
        for line in file:
            data.append(json.loads(line.strip()))
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(data)
    df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
    # 그래프 그리기
    plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# 그래프 꾸미기
plt.xlabel('Index')
plt.ylabel('FID50k Full')
plt.title('FID50k Full Comparison Across Models')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 그래프 초기화
# plt.figure(figsize=(12, 8))

# # 각 파일 데이터를 읽고 플롯
# for label, filepath in two_step.items():
#     # 데이터 로드
#     data = []
#     with open(filepath, 'r') as file:
#         for line in file:
#             data.append(json.loads(line.strip()))
    
#     # pandas DataFrame으로 변환
#     df = pd.DataFrame(data)
#     df['fid50k_full'] = df['results'].apply(lambda x: x['fid50k_full'])
    
#     # 그래프 그리기
#     plt.plot(df.index, df['fid50k_full'], marker='o', color=colors[label], label=label)

# # 그래프 꾸미기
# plt.xlabel('Index')
# plt.ylabel('FID50k Full')
# plt.title('Two-step-FID50k Full Comparison Across Models')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()
